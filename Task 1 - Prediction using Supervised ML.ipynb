# %% [markdown]
# # GRIP - The Spark Foundation
# # Jevin Jain
# # Task 1 - Prediction using Supervised ML

# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np  
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
# %matplotlib inline

from sklearn.metrics import (
    mean_squared_error, 
    mean_absolute_error, 
    r2_score)

# %% [markdown]
# # Reading Dataset

# %%
studentscores_df = pd.read_csv('student_scores.csv')
studentscores_df.head()
# Out:
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30

# %% [markdown]
# # Scatter Plot

# %%
studentscores_df.plot(x='Hours', y='Scores', style='o', c='red')
plt.title('Hours vs Percentage', fontsize=20)  
plt.xlabel('Hours Studied', fontsize=20)  
plt.ylabel('Percentage Score', fontsize=20)  
plt.show()

# %% [markdown]
# # Data Preparation

# %%
X = studentscores_df.iloc[:, :-1].values  
y = studentscores_df.iloc[:, 1].values

# %%
from sklearn.model_selection import train_test_split  
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                            test_size=0.2, random_state=0)

# %% [markdown]
# # Model Training

# %%
from sklearn.linear_model import LinearRegression  
regressor = LinearRegression()  
regressor.fit(X_train, y_train)

y_test_pred = regressor.predict(X_test)
y_train_pred = regressor.predict(X_train)

# %% [markdown]
# # Plotting Linear Fit Line

# %%
plt.scatter(X_train, y_train)
plt.plot(X_train, y_train_pred, color='red')
plt.show()

# %%
plt.scatter(X_test, y_test)
plt.plot(X_test, y_test_pred, color='red')
plt.show()

# %% [markdown]
# # Performance Metrics of Linear Regression

# %%
print("Linear Regression results:")
print("- R2:")
print('  - Train set R2: ', r2_score(y_train, y_train_pred))
print('  - Test set R2: ', r2_score(y_test, y_test_pred))
print()
print("- MAE: ")
print('  - Train MAE: ', mean_absolute_error(y_train, y_train_pred))
print('  - Test MAE: ', mean_absolute_error(y_test, y_test_pred))
print()
print("- MSE: ")
print('  - Train MSE: ', mean_squared_error(y_train, y_train_pred))
print('  - Test MSE: ', mean_squared_error(y_test, y_test_pred))
# Out:
# Linear Regression results:
# - R2:
#   - Train set R2:  0.9515510725211552
#   - Test set R2:  0.9454906892105355
#
# - MAE:
#   - Train MAE:  5.186601709180371
#   - Test MAE:  4.183859899002975
#
# - MSE:
#   - Train MSE:  30.89818237731452
#   - Test MSE:  21.598769307217406

# %% [markdown]
# # Prediction using Supervised ML

# %%
hours = float(input('Enter number of hours/day the student studies: '))
prediction = regressor.predict([[hours]])

print("Number of hours/day the student studies = {}".format(hours))  
print("Then the predicted score is = {}".format(prediction[0]))
